# %% [markdown]
# <a href="https://colab.research.google.com/github/ChitrakCDB/MachineLearningAlgorithms/blob/main/K_MeansClustering_LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  #does mathematical operation
import matplotlib.pyplot as plt #For plotting the graphs
import pandas as pd #making the data frames and import the csv files

# %%
from google.colab import drive #to import the google drive data

# %%
drive.mount('/content/drive')   # to mount the drive data into the colab cloud and enter the activation code
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/"My Drive/Colab Notebooks/Files"
# Out:
# /content/drive/My Drive/Colab Notebooks/Files

# %%
df1 = pd.read_excel("kmean.xlsx",sheet_name='ex7data2_X',header=None)

# %%
df1.head()
# Out:
#           0         1
# 0  1.842080  4.607572
# 1  5.658583  4.799964
# 2  6.352579  3.290854
# 3  2.904017  4.612204
# 4  3.231979  4.939894

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
X = np.array(df1)   #convert dataframe to array

# %%
import random

# %%
init_centroids = random.sample(range(0,len(df1)),4)

# %%
init_centroids      #index of the points
# Out:
# [19, 81, 92, 255]

# %%
centroids=[]
for i in init_centroids:
    centroids.append(df1.iloc[i])

# %%
print(centroids)
# Out:
# [0    3.162187
# 1    4.836583
# Name: 19, dtype: float64, 0    2.286648
# 1    5.007670
# Name: 81, dtype: float64, 0    0.177835
# 1    5.297650
# Name: 92, dtype: float64, 0    6.242571
# 1    2.791793
# Name: 255, dtype: float64]

# %%
centroids = np.array(centroids)

# %%
centroids
# Out:
# array([[3.1621865 , 4.83658301],
#        [2.28664839, 5.0076699 ],
#        [0.17783466, 5.29765032],
#        [6.24257071, 2.79179269]])

# %%
def calc_distance(X1,X2):
    return ((sum(X1-X2)**2)**0.5)

# %%
def findclosestcentroid(c,X):
    assign_centroids=[]
    for i in X:
        distance_list=[]
        for j in c:
            distance_list.append(calc_distance(i,j))
        assign_centroids.append(np.argmin(distance_list))
    return assign_centroids

# %%
get_centroid = findclosestcentroid(centroids,X)

# %%
def calc_centroids(cluster,X):
    new_centroid = []
    new_df1 = pd.concat([pd.DataFrame(X),pd.DataFrame(cluster,columns=['clusters'])],axis=1)
    for c in set(new_df1['clusters']):
        current_cluster = new_df1[new_df1['clusters']==c][new_df1.columns[:-1]]        #Consodering all the X and Y values for particular cluster C
        current_mean = current_cluster.mean(axis=0)
        new_centroid.append(current_mean)
    return new_centroid

# %%
for i in range(30):
    get_centroid = findclosestcentroid(centroids,X)     #we have obtained the cluster number for each observation
    centroids = calc_centroids(get_centroid,X)

    #Visulaization
    plt.figure()
    plt.scatter(np.array(centroids)[:,0],np.array(centroids)[:,1],color='black')    #Plot the Centroids point
    plt.scatter(X[:,0],X[:,1],color='yellow',alpha=0.5) 
    plt.show()

# %%
import cv2

# %%
im = cv2.imread('tom.jpeg')

# %%
im
# Out:
# array([[[165, 197, 220],
#         [163, 199, 217],
#         [151, 191, 203],
#         ...,
#         [ 44, 197, 252],
#         [ 43, 195, 250],
#         [ 44, 196, 251]],
#
#        [[174, 206, 225],
#         [171, 205, 221],
#         [164, 203, 212],
#         ...,
#         [ 42, 197, 252],
#         [ 42, 197, 252],
#         [ 40, 195, 250]],
#
#        [[185, 217, 230],
#         [181, 216, 226],
#         [179, 216, 224],
#         ...,
#         [ 32, 191, 247],
#         [ 34, 197, 252],
#         [ 33, 198, 253]],
#
#        ...,
#
#        [[ 60, 139, 158],
#         [ 64, 143, 162],
#         [ 66, 145, 164],
#         ...,
#         [ 96, 189, 210],
#         [ 99, 189, 213],
#         [ 97, 187, 211]],
#
#        [[ 62, 139, 158],
#         [ 63, 142, 161],
#         [ 65, 144, 163],
#         ...,
#         [ 98, 191, 212],
#         [101, 191, 215],
#         [102, 192, 216]],
#
#        [[ 64, 141, 160],
#         [ 66, 143, 162],
#         [ 66, 145, 164],
#         ...,
#         [ 99, 192, 213],
#         [100, 190, 214],
#         [ 98, 188, 212]]], dtype=uint8)

# %%
im.shape
# Out:
# (200, 200, 3)

# %%
im = (im/255).reshape(200*200,3)

# %%
init_centroids = random.sample(range(0,len(im)),10)

# %%
init_centroids
# Out:
# [1163, 24387, 27131, 23292, 4608, 39265, 29893, 5760, 27237, 15428]

# %%
centroids=[]
for i in init_centroids:
    centroids.append(im[i])

# %%
centroids = np.array(centroids)

# %%
centroids
# Out:
# array([[0.43529412, 0.58823529, 0.50196078],
#        [0.0745098 , 0.78823529, 0.71764706],
#        [0.08627451, 0.12941176, 0.16078431],
#        [0.08235294, 0.12156863, 0.14901961],
#        [0.01176471, 0.07843137, 0.78431373],
#        [0.20784314, 0.54117647, 0.6       ],
#        [0.58431373, 0.61960784, 0.6745098 ],
#        [0.68235294, 0.79607843, 0.69803922],
#        [0.10196078, 0.8       , 0.77254902],
#        [0.09019608, 0.50980392, 0.98431373]])

# %%
for i in range(2):
    print(i)
    get_centroid = findclosestcentroid(centroids,im)     #we have obtained the cluster number for each observation
    centroids = calc_centroids(get_centroid,im)
# Out:
# 0
# 1
